# %% [markdown]
# <div style="display: flex; justify-content: center; margin-top: 20px;">
#     <table style="width: 70%; border-collapse: collapse; background-color: #f0f5e3; color: #3e4b3b; font-family: Arial, sans-serif;">
#         <!-- Bird Name Row -->
#         <tr>
#             <th colspan="2" style="text-align: center; padding: 15px; font-size: 24px; background-color: #8fbf82; color: #3e4b3b;">
#                 <span style="font-weight: bold;">[Bird Common Name]</span>
#                 <br>
#                 <em style="font-size: 16px;">[Bird Scientific Name]</em>
#             </th>
#         </tr>
#         <!-- Secondary Information Row -->
#         <tr>
#             <!-- Category Cell -->
#             <td style="padding: 10px; border: 1px solid #d0d9c6; vertical-align: top;">
#                 <strong>Category:</strong> <br>
#                 [e.g., Migratory, Resident]
#             </td>
#             <!-- Description Cell -->
#             <td style="padding: 10px; border: 1px solid #d0d9c6; vertical-align: top;">
#                 <strong>Description:</strong> <br>
#                 [Brief description of the bird, including unique features, habitat preferences, or any interesting facts.]
#             </td>
#         </tr>
#     </table>
# </div>

# %%
from IPython.display import Image, display

# Display image below the table
display(Image(filename="Alameda-3260.jpg"))
